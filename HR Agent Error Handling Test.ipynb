# %%
# %run "/Users/neethu.mv@tigeranalytics.com/DatabricksAgentCreation/Multi-Tool HR Agent"
# Out:
# 2026/09/07 18:39:35 WARNING mlflow.tracking.context.registry: Encountered unexpected error during resolving tags: An error occurred while calling o10.extraContext. Trace:
# py4j.security.Py4JSecurityException: Method public scala.collection.immutable.Map com.databricks.backend.common.rpc.CommandContext.extraContext() is not whitelisted on class class com.databricks.backend.common.rpc.CommandContext
# 	at py4j.security.WhitelistingPy4JSecurityManager.checkCall(WhitelistingPy4JSecurityManager.java:473)
# 	at py4j.Gateway.invoke(Gateway.java:305)
# 	at com.databricks.backend.daemon.driver.InstrumentedCallCommand.$anonfun$invokeMethod$1(InstrumentedCallCommand.scala:19)
# 	at com.databricks.backend.daemon.driver.InstrumentedPy4jCommand.instrumentedInvoke(InstrumentedPy4jCommand.scala:28)
# 	at com.databricks.backend.daemon.driver.InstrumentedPy4jCommand.instrumentedInvoke$(InstrumentedPy4jCommand.scala:18)
# ...

# %%
# Step 2: Test hr_agent with an intentionally invalid Genie space ID ("123")
# to demonstrate how the agent behaves when the Genie space does not exist.
# Expected: the Genie API returns a NotFound error because space "123" is invalid.
BROKEN_SPACE_ID = "123"

print(
    hr_agent(
        "How many active employees do we have?",
        BROKEN_SPACE_ID
    )
)
# Out:
# Trace(trace_id=tr-8ae9dc3aaa84be121b2fbf027417da2d)
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# File <command-5548393351547411>, line 4
#       1 BROKEN_SPACE_ID = "123"
#       3 print(
# ----> 4     hr_agent(
#       5         "How many active employees do we have?",
#       6         BROKEN_SPACE_ID
#       7     )
#       8 )
#
# File /databricks/python/lib/python3.12/site-packages/mlflow/tracing/fluent.py:262, in _wrap_function.<locals>.wrapper(*args, **kwargs)
#     261 def wrapper(*args, **kwargs):
# --> 262     with _WrappingContext(fn, args, kwargs) as wrapping_coro:
#     263         return wrapping_coro.send(fn(*args, **kwargs))
#
# File /databricks/python/lib/python3.12/site-packages/mlflow/tracing/fluent.py:251, in _wrap_function.<locals>._WrappingContext.__exit__(self, exc_type, exc_value, traceback)
# ...
